# %%
import numpy as np

from load_utils.load import *
import nltk

# %% [markdown]
# # Data Loading into Data Frame

# %%
data = text2array("sentiment.txt")
yelp = text2array("yelp.txt", is_yelp=True)
amazon = text2array("amazon.txt", is_yelp=True)
imdb = text2array("imdb.txt", is_yelp=True)

data = array2df([*data, *yelp, *amazon, *imdb])

# %%
data.head()
# Out:
#                                                 text label
# 0          The Da Vinci Code book is just awesome.\n     1
# 1  this was the first clive cussler i've ever rea...     1
# 2                 i liked the Da Vinci Code a lot.\n     1
# 3                 i liked the Da Vinci Code a lot.\n     1
# 4  I liked the Da Vinci Code but it ultimatly did...     1

# %% [markdown]
# # Natural Language Processing

# %% [markdown]
# ## Standartizing

# %%
def standartize(df):
    lookup_table = {
        "'ve": "have",
        "'re": "are",
        "'s": "is",
        "n't": "not",
        "'d": "had"
    }
    
    for i in range(len(df)):
        text = df.iloc[i]["text"].lower()
        sents = nltk.sent_tokenize(text)
        
        for j in range(len(sents)):
            words = nltk.word_tokenize(sents[j])
            for k in range(len(words)):
                if words[k] in lookup_table.keys():
                    words[k] = lookup_table[words[k]]
   
            sents[j] = " ".join(words)
        
        text = " ".join(sents)
        df.iloc[i]["text"] = text

# %%
standartize(data)

# %%
data
# Out:
#                                                     text label
# 0               the da vinci code book is just awesome .     1
# 1      this was the first clive cussler i have ever r...     1
# 2                      i liked the da vinci code a lot .     1
# 3                      i liked the da vinci code a lot .     1
# 4      i liked the da vinci code but it ultimatly did...     1
# 5      that is not even an exaggeration ) and at midn...     1
# 6      i loved the da vinci code , but now i want som...     1
# 7      i thought da vinci code was great , same with ...     1
# 8         the da vinci code is actually a good movie ...     1
# 9      i thought the da vinci code was a pretty good ...     1
# 10     the da vinci code is one of the most beautiful...     1
# 11     the da vinci code is an * amazing * book , do ...     1
# 12     then i turn on the light and the radio and enj...     1
# 13                   the da vinci code was really good .     1
# 14                            i love da vinci code ... .     1
# 15                               i loved da vinci code..     1
# 16     to night : : the da vinci code and a beautiful...     1
# 17            the da vinci code is an awesome book ... .     1
# 18              thing is , i enjoyed the da vinci code .     1
# 19               very da vinci code slash amazing race .     1
# 20                    hey i loved the da vinci code ! ..     1
# 21                        also loved the da vinci code..     1
# 22     i really enjoyed the da vinci code but thought...     1
# 23     i do like angels and demons more then the da v...     1
# 24           the da vinci code was a really good movie .     1
# 25     yeah , da vinci code is an awesome movie i lik...     1
# 26                     i really like the da vinci code .     1
# 27                            da vinci code is amazing .     1
# 28                     the da vinci code was awesome ...     1
# 29     the da vinci code is backtory on various relig...     1
# ...                                                  ...   ...
# 10056  enough can not be said of the remarkable anima...   1\n
# 10057  the art style has the appearance of crayon/pen...   1\n
# 10058  if you act in such a film , you should be glad...   0\n
# 10059  this one wants to surf on the small wave of sp...   0\n
# 10060  if you have not choked in your own vomit by th...   0\n
# 10061  still , it makes up for all of this with a sup...   1\n
# 10062  just consider the excellent story , solid acti...   1\n
# 10063  instead , we got a bore fest about a whiny , s...   0\n
# 10064  then i watched it again two sundays ago ( marc...   1\n
# 10065        it is a very well acted and done tv movie .   1\n
# 10066  judith light is one of my favorite actresses a...   1\n
# 10067                 i keep watching it over and over .   1\n
# 10068                it is a sad movie , but very good .   1\n
# 10069  if you have not seen this movie , i definitely...   1\n
# 10070           she is as lovely as usual , this cutie !   1\n
# 10071  still it is quite interesting and entertaining...   1\n
# 10072                    ; ) recommend with confidence !   1\n
# 10073  this movie is well-balanced with comedy and dr...   1\n
# 10074  it was a riot to see hugo weaving play a sex-o...   1\n
# 10075  : ) anyway , the plot flowed smoothly and the ...   1\n
# 10076  the opening sequence of this gem is a classic ...   1\n
# 10077              fans of the genre will be in heaven .   1\n
# 10078                 lange had become a great actress .   1\n
# 10079                 it looked like a wonderful story .   1\n
# 10080             i never walked out of a movie faster .   0\n
# 10081  i just got bored watching jessice lange take h...   0\n
# 10082  unfortunately , any virtue in this film is pro...   0\n
# 10083                   in a word , it is embarrassing .   0\n
# 10084                                exceptionally bad !   0\n
# 10085  all in all its an insult to one is intelligenc...   0\n
#
# [10086 rows x 2 columns]
